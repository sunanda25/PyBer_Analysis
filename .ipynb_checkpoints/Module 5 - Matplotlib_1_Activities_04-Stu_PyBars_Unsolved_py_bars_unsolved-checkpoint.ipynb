# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
cities = ["New Orleans", "Milwaukee", "Omaha", "Pittsburgh", "Toledo"]
bars_in_cities = [8.6, 8.5, 8.3, 7.9, 7.2]
x_axis = np.arange(len(bars_in_cities))

# %%
# Create a bar chart based upon the above data
plt.bar(x_axis,bars_in_cities, label=cities, color= "blue")
# Out:
# <img src="data:image/png;base64,..." width="640">
# <BarContainer object of 5 artists>

# %%
# Create the ticks for our bar chart's x axis
plt.xticks(x_axis, ["New Orleans", "Milwaukee", "Omaha", "Pittsburgh", "Toledo"])
# Out:
# ([<matplotlib.axis.XTick at 0x8ff0710>,
#   <matplotlib.axis.XTick at 0x8ff0490>,
#   <matplotlib.axis.XTick at 0x8ff01f0>,
#   <matplotlib.axis.XTick at 0x9006e50>,
#   <matplotlib.axis.XTick at 0x9013110>],
#  [Text(0, 0, 'New Orleans'),
#   Text(1, 0, 'Milwaukee'),
#   Text(2, 0, 'Omaha'),
#   Text(3, 0, 'Pittsburgh'),
#   Text(4, 0, 'Toledo')])

# %%
# Set the limits of the x axis
plt.xlim(-0.75, len(x_axis))
# Out:
# (-0.75, 5.0)

# %%
# Set the limits of the y axis
plt.ylim(0, 9)
# Out:
# (0.0, 9.0)

# %%
# Give the chart a title, x label, and y label
plt.title("Density of Bars in Cities")
plt.xlabel("Cities")
plt.ylabel("Bars per 10,000 Households")
# Out:
# Text(0, 0.5, 'Bars per 10,000 Households')

# %%
# Save an image of the chart and print it to the screen
plt.savefig("Density of bars in cities.png")
