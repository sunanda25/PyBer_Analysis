# %%
# Import Dependencies
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# Import our data into pandas from CSV
bike_trips_df=pd.read_csv("Resources/trip.csv", low_memory = False)
bike_trips_df.head()
# Out:
#            stoptime    bikeid  tripduration    from_station_name  \
# 0  10/13/2014 10:48  SEA00298       985.935  2nd Ave & Spring St
# 1  10/13/2014 10:48  SEA00195       926.375  2nd Ave & Spring St
# 2  10/13/2014 10:48  SEA00486       883.831  2nd Ave & Spring St
# 3  10/13/2014 10:48  SEA00333       865.937  2nd Ave & Spring St
# 4  10/13/2014 10:49  SEA00202       923.923  2nd Ave & Spring St
#
#                                      to_station_name from_station_id  \
# 0  Occidental Park / Occidental Ave S & S Washing...          CBD-06
# 1  Occidental Park / Occidental Ave S & S Washing...          CBD-06
# 2  Occidental Park / Occidental Ave S & S Washing...          CBD-06
# 3  Occidental Park / Occidental Ave S & S Washing...          CBD-06
# 4  Occidental Park / Occidental Ave S & S Washing...          CBD-06
#
#   to_station_id usertype  gender birthyear
# 0         PS-04   Member    Male      1960
# 1         PS-04   Member    Male      1970
# 2         PS-04   Member  Female      1988
# 3         PS-04   Member  Female      1977
# 4         PS-04   Member    Male      1971

# %%
#  Get the names of the columns.
bike_trips_df.columns
# Out:
# Index(['stoptime', 'bikeid', 'tripduration', 'from_station_name',
#        'to_station_name', 'from_station_id', 'to_station_id', 'usertype',
#        'gender', 'birthyear'],
#       dtype='object')

# %%
# Check for null or NaNs.
bike_trips_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 286858 entries, 0 to 286857
# Data columns (total 10 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   stoptime           286858 non-null  object
#  1   bikeid             286858 non-null  object
#  2   tripduration       286858 non-null  float64
#  3   from_station_name  286858 non-null  object
#  4   to_station_name    286858 non-null  object
#  5   from_station_id    286858 non-null  object
#  6   to_station_id      286858 non-null  object
#  7   usertype           286858 non-null  object
#  8   gender             181558 non-null  object
#  9   birthyear          181554 non-null  object
# dtypes: float64(1), object(9)
# memory usage: 12.0+ MB

# %%
# Create a clean DataFrame after dropping the null values.
clean_df= bike_trips_df.dropna()
clean_df.head()
# Out:
#            stoptime    bikeid  tripduration    from_station_name  \
# 0  10/13/2014 10:48  SEA00298       985.935  2nd Ave & Spring St
# 1  10/13/2014 10:48  SEA00195       926.375  2nd Ave & Spring St
# 2  10/13/2014 10:48  SEA00486       883.831  2nd Ave & Spring St
# 3  10/13/2014 10:48  SEA00333       865.937  2nd Ave & Spring St
# 4  10/13/2014 10:49  SEA00202       923.923  2nd Ave & Spring St
#
#                                      to_station_name from_station_id  \
# 0  Occidental Park / Occidental Ave S & S Washing...          CBD-06
# 1  Occidental Park / Occidental Ave S & S Washing...          CBD-06
# 2  Occidental Park / Occidental Ave S & S Washing...          CBD-06
# 3  Occidental Park / Occidental Ave S & S Washing...          CBD-06
# 4  Occidental Park / Occidental Ave S & S Washing...          CBD-06
#
#   to_station_id usertype  gender birthyear
# 0         PS-04   Member    Male      1960
# 1         PS-04   Member    Male      1970
# 2         PS-04   Member  Female      1988
# 3         PS-04   Member  Female      1977
# 4         PS-04   Member    Male      1971

# %%
# Split up the data into groups based upon 'gender' and 'stoptime'
# And, find out how many bike trips each gender took.
gender_stoptime = clean_df.groupby(["gender", "stoptime"]).count()["tripduration"].reset_index(name="no_trips")
gender_stoptime
# Out:
#           gender         stoptime  no_trips
# 0         Female   1/1/2015 11:01         2
# 1         Female   1/1/2015 11:54         2
# 2         Female   1/1/2015 12:22         2
# 3         Female   1/1/2015 13:16         4
# 4         Female   1/1/2015 13:32         2
# ...          ...              ...       ...
# 131210     Other   9/9/2015 21:41         1
# 131211     Other    9/9/2015 7:44         1
# 131212     Other    9/9/2015 8:35         1
# 131213     Other    9/9/2015 9:44         1
# 131214  stoptime  4/17/2015 19:21         1
#
# [131215 rows x 3 columns]

# %%
# Reset the index of the Pandas Series to convert to a DataFrame.

# %%
# Get the datatypes for the DataFrame columns.
gender_stoptime.dtypes
# Out:
# gender      object
# stoptime    object
# no_trips     int64
# dtype: object

# %%
#  Change the 'stoptime' column to a datetime object.
gender_stoptime["stoptime"]= pd.to_datetime(gender_stoptime["stoptime"])

# %%
# Check the datatypes for each column.
gender_stoptime.dtypes
# Out:
# gender              object
# stoptime    datetime64[ns]
# no_trips             int64
# dtype: object

# %%
# Check the DataFrame.
gender_stoptime
# Out:
#           gender            stoptime  no_trips
# 0         Female 2015-01-01 11:01:00         2
# 1         Female 2015-01-01 11:54:00         2
# 2         Female 2015-01-01 12:22:00         2
# 3         Female 2015-01-01 13:16:00         4
# 4         Female 2015-01-01 13:32:00         2
# ...          ...                 ...       ...
# 131210     Other 2015-09-09 21:41:00         1
# 131211     Other 2015-09-09 07:44:00         1
# 131212     Other 2015-09-09 08:35:00         1
# 131213     Other 2015-09-09 09:44:00         1
# 131214  stoptime 2015-04-17 19:21:00         1
#
# [131215 rows x 3 columns]

# %%
# Create a pivot table with the 'stoptime' as the index and the columns ='gender' with the trip counts in each row.
gender_stoptime_pv= gender_stoptime.pivot(index= "stoptime", columns = "gender", values= "no_trips")

# %%
# Drop the stoptime column.
gender_stoptime_pv.drop("stoptime", axis=1, inplace=True)

# %%
# Create a new DataFrame from the pivot table DataFrame by filtering for the given dates, '2015-01-01':'2015-12-31'. 
gender_stoptime_jan_dec = gender_stoptime_pv.loc['2015-01-01':'2015-12-31']
gender_stoptime_jan_dec
# Out:
# gender               Female  Male  Other
# stoptime
# 2015-01-01 00:44:00     NaN   2.0    NaN
# 2015-01-01 00:48:00     NaN   2.0    NaN
# 2015-01-01 03:18:00     NaN   2.0    NaN
# 2015-01-01 08:20:00     NaN   2.0    NaN
# 2015-01-01 11:01:00     2.0   NaN    NaN
# ...                     ...   ...    ...
# 2015-12-31 20:27:00     NaN   1.0    NaN
# 2015-12-31 21:23:00     NaN   1.0    NaN
# 2015-12-31 21:25:00     NaN   1.0    NaN
# 2015-12-31 22:34:00     NaN   1.0    NaN
# 2015-12-31 23:04:00     NaN   1.0    NaN
#
# [73092 rows x 3 columns]

# %%
# Resample the DataFrame by the week. ie., "W", and get the trip counts for each week. 
resample_df= gender_stoptime_jan_dec.resample("w").count()
resample_df
# Out:
# gender      Female  Male  Other
# stoptime
# 2015-01-04      68   206      5
# 2015-01-11     247   944      5
# 2015-01-18     226   963     11
# 2015-01-25     313   992     17
# 2015-02-01     294  1036     23
# 2015-02-08     199   783      8
# 2015-02-15     281  1104     24
# 2015-02-22     252   923     31
# 2015-03-01     234   886     27
# 2015-03-08     363  1063     28
# 2015-03-15     357   981     17
# 2015-03-22     324   945     26
# 2015-03-29     352   999     26
# 2015-04-05     301  1067     30
# 2015-04-12     329  1121     28
# 2015-04-19     399  1175     26
# 2015-04-26     371  1245     32
# 2015-05-03     419  1192     24
# 2015-05-10     539  1308     31
# 2015-05-17     417  1297     37
# 2015-05-24     477  1303     16
# 2015-05-31     462  1251     26
# 2015-06-07     459  1278     28
# 2015-06-14     466  1452     22
# 2015-06-21     412  1329     45
# 2015-06-28     451  1377     45
# 2015-07-05     417  1377     41
# 2015-07-12     438  1527     38
# 2015-07-19     447  1527     54
# 2015-07-26     449  1408     51
# 2015-08-02     437  1434     56
# 2015-08-09     453  1483     56
# 2015-08-16     384  1401     42
# 2015-08-23     380  1473     45
# 2015-08-30     343  1392     52
# 2015-09-06     308  1282     47
# 2015-09-13     336  1200     48
# 2015-09-20     325  1221     33
# 2015-09-27     400  1342     21
# 2015-10-04     403  1344     34
# 2015-10-11     326  1217     33
# 2015-10-18     351  1241     26
# 2015-10-25     339  1306     32
# 2015-11-01     295  1102     26
# 2015-11-08     278  1062     22
# 2015-11-15     247   965     23
# 2015-11-22     258   950     25
# 2015-11-29     140   604     26
# 2015-12-06     243   886     20
# 2015-12-13     227   746     19
# 2015-12-20     245   860     12
# 2015-12-27     118   390     10
# 2016-01-03      91   368      6

# %%
# Plot the resampled DataFrame.
resample_df.plot(figsize= (20,6))
plt.xlabel("Month")
plt.ylabel("Rides")
# Add a title 
plt.title("Number of Rides")
#  Add a x- and y-axis label.
# Out:
# Text(0.5, 1.0, 'Number of Rides')
